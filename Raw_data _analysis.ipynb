# %%
import pandas as pd
pd.set_option('display.max_rows', 500)

# %%
df = pd.read_csv('MidasExport.csv',encoding = "ISO-8859-1")
# Out:
# /Users/stevendirjayanto/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (2,3,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
len(df.columns)
# Out:
# 86

# %%
len(df[df.ClientCountry != "United States"])
# Out:
# 6915

# %%
df[df.CostPTD < 0]
# Out:
#         AccountingPeriod        PeriodEndDate ProjectCode ProjectFamily  \
# 10381             200412  2004-11-28 00:00:00   230208902       2302089
# 10382             200412  2004-12-05 00:00:00   230208902       2302089
# 10383             200412  2004-12-26 00:00:00   230208902       2302089
# 10384             200501  2005-01-23 00:00:00   230208902       2302089
# 10385             200503  2005-03-27 00:00:00   230208902       2302089
# 10386             200505  2005-05-22 00:00:00   230208902       2302089
# 10387             200506  2005-06-26 00:00:00   230208902       2302089
# 11463             200305  2003-05-11 00:00:00   230302600       2303026
# 12658             200402  2004-02-15 00:00:00   230307201       2303072
# 12659             200405  2004-05-23 00:00:00   230307201       2303072
# 12847             200402  2004-02-15 00:00:00   230307401       2303074
# 16209             200702  2007-02-04 00:00:00   230404007       2304040
# ...

# %%
df.ClientState.unique()
# Out:
# array(['Texas', 'Nevada', 'Missouri', 'Florida', 'New York', 'Georgia',
#        'Pennsylvania', 'New Jersey', 'Maryland', 'Ohio', 'Kansas',
#        'Ontario', 'Oklahoma', 'North Carolina', 'Illinois', 'Louisiana',
#        'Massachusetts', 'Virginia', 'California', 'Tennessee',
#        'Wisconsin', 'Arizona', 'Quebec', 'Colorado', 'Iowa', 'New Mexico',
#        'Minnesota', 'District Of Columbia', 'Oregon', 'Indiana',
#        'Mississippi', 'Kentucky', 'Nebraska', 'Virgin Islands',
#        'Washington', 'England', 'Alabama', 'Arkansas', 'South Carolina',
#        'Connecticut', 'Rhode Island', 'Montana', 'Utah', 'Michigan',
#        'Saskatchewan', 'Idaho', 'Smith', 'British Columbia', 'Alberta',
#        'Queretaro, Qro.', 'District Federal', 'Rostock', 'Maine',
#        'Vermont', 'Nassau', 'Panama City', 'Baden-Württemberg',
#        'Nuevo Leon', 'New Hampshire', 'San Jose', 'Lagos', 'London',
#        'Brazil', 'Al-Khobar', 'Abu Dhabi', 'Stockholm', 'Vic', 'Hamburg',
# ...

# %%
df_short = df[['ProjectCode','BillingMTD', 'BillingPTD', 'ClientCity', 'ClientCountry', 'ClientState','ClientCode', 'ClientTypeName',
       'CostMTD', 'CostPTD', 'EffortAmtPED','EmpCountPED', 'HoursPTD', 'IndiaCountPED',
       'IndiaHrsPED', 'LaborRevenueMTD', 'LaborRevenuePTD', 'NonIndiaHrsPED',
       'OverheadMTD', 'OverheadPTD','OwningOrgName', 'ProjectEngineer', 'ProjectManager', 'TotalBudgetCost',
       'TotalBudgetEffort', 'TotalBudgetHours', 'TotalHoursPED', 'DrafterAvgExp', 'DrafterCombinedExp', 'DrafterHoursPED',
       'DrafterUniqueCount', 'EngAvgExp', 'EngCombinedExp',
       'EngHoursPED', 'EngPctPED', 'EngProjectCountPED', 'EngUniqueCount',
       'OtherAvgExp', 'OtherCombinedExp', 'OtherHoursPED', 'OtherPctPED',
       'OtherUniqueCount', 'PMProjectCountPED', 'PrincipalProjectCountPED',
       'FamilyProjectCount', 'FamilyEffortPTD', 'FamilyCostPTD',
       'FamilyOverheadPTD', 'FamilyHoursPTD', 'FamilyRevenuePTD',
       'FamilyBudgetEffort', 'FamilyEffortMTD', 'FamilyCostMTD',
       'FamilyOverheadMTD', 'FamilyRevenueMTD', 'FamilyHoursPED',
       'FamilyEffortPED', 'FamilyIndiaCountPED', 'FamilyIndiaHrsPED',
       'LaborEffortPED', 'LaborCostPED', 'LaborHrsPED', 'RevenueMTD',
       'LaborCostMTD', 'LaborOverheadMTD', 'RevenuePTD', 'LaborCostPTD',
       'LaborOverheadPTD', 'TotalLaborBudgetEffort']]

# %%
df_short.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 464585 entries, 0 to 464584
# Data columns (total 69 columns):
# ProjectCode                 464585 non-null object
# BillingMTD                  464585 non-null float64
# BillingPTD                  464585 non-null float64
# ClientCity                  464585 non-null object
# ClientCountry               464585 non-null object
# ClientState                 464585 non-null object
# ClientCode                  464579 non-null object
# ClientTypeName              464585 non-null object
# CostMTD                     464585 non-null float64
# CostPTD                     464585 non-null float64
# EffortAmtPED                464585 non-null float64
# EmpCountPED                 464585 non-null int64
# HoursPTD                    464585 non-null float64
# IndiaCountPED               464585 non-null int64
# IndiaHrsPED                 464585 non-null float64
# LaborRevenueMTD             464585 non-null float64
# ...

# %%
df_short['ProjectCode'] = df_short['ProjectCode'].astype('|S')
df_no_15 = df_short[df_short.ProjectCode.str[:2] != b'15']
df_no_15['ProjectCode'] = df_no_15['ProjectCode'].str[:8]
# Out:
# /Users/stevendirjayanto/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/stevendirjayanto/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_grouped = df_no_15.groupby('ProjectCode')

# %%
df_grouped.get_group(b'23000020')
# Out:
#         ProjectCode  BillingMTD  BillingPTD ClientCity  ClientCountry  \
# 39      b'23000020'        0.00        0.00    HOUSTON  United States
# 40      b'23000020'     1000.00     1000.00    HOUSTON  United States
# 41      b'23000020'        0.00     1000.00    HOUSTON  United States
# 42      b'23000020'        0.00     1000.00    HOUSTON  United States
# 43      b'23000020'     4000.00     5000.00    HOUSTON  United States
# 44      b'23000020'        0.00     5000.00    HOUSTON  United States
# 45      b'23000020'        7.37     5007.37    HOUSTON  United States
# 46      b'23000020'        0.00     5007.37    HOUSTON  United States
# 47      b'23000020'        0.00     5007.37    HOUSTON  United States
# 48      b'23000020'        0.00        0.00    HOUSTON  United States
# 49      b'23000020'        0.00        0.00    HOUSTON  United States
# 50      b'23000020'        0.00        0.00    HOUSTON  United States
# ...

# %%
df_grouped.ClientState.unique()
# Out:
# ProjectCode
# b'12040010'                      [Texas]
# b'23000020'                      [Texas]
# b'23000036'                      [Texas]
# b'23000280'                   [Missouri]
# b'23000320'                      [Texas]
# b'23000330'                      [Texas]
# b'23000360'                      [Texas]
# b'23000430'                      [Texas]
# b'23000500'                      [Texas]
# b'23000530'                      [Texas]
# b'23000550'                      [Texas]
# b'23000551'                      [Texas]
# b'23000552'                      [Texas]
# b'23000590'                      [Texas]
# b'23000610'                      [Texas]
# b'23000640'                    [Florida]
# b'23000710'                      [Texas]
# b'23000711'                      [Texas]
# b'23000830'                      [Texas]
# b'23000920'                      [Texas]
# b'23000950'                      [Texas]
# b'23000980'                      [Texas]
# ...

# %%
df_numeric = df_grouped.sum()
len(df_numeric.columns)
# Out:
# 61

# %%
df_more = df_short[['ProjectCode', 'ClientCountry', 'ClientTypeName',
       'CostMTD', 'CostPTD',
       'OverheadMTD', 'OverheadPTD', 'DrafterAvgExp', 'DrafterCombinedExp', 'DrafterHoursPED',
       'DrafterUniqueCount', 'EngAvgExp', 'EngCombinedExp',
       'EngHoursPED', 'EngPctPED', 'EngProjectCountPED', 'EngUniqueCount',
       'OtherAvgExp', 'OtherCombinedExp', 'OtherHoursPED', 'OtherPctPED',
       'OtherUniqueCount', 'PMProjectCountPED', 'PrincipalProjectCountPED',  'RevenueMTD',
        'RevenuePTD']]
df_more['ProjectCode'] = df_more['ProjectCode'].astype('|S')
df_more = df_more[df_more.ProjectCode.str[:2] != b'15']
df_more['ProjectCode'] = df_more['ProjectCode'].str[:8]
df_more['ProfitPTD'] = df_more['RevenuePTD'] - df_more['CostPTD'] - df_more['OverheadPTD']
df_more['Profit%PTD'] = df_more['ProfitPTD']/df['RevenuePTD']
df_more = df_more.groupby('ProjectCode').max()
# Out:
# /Users/stevendirjayanto/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
import matplotlib.pyplot as plt
plt.plot(df_more['DrafterUniqueCount'],df_more["Profit%PTD"],'ro')

# %%
df_more['Profit%PTD'].max()
# Out:
# inf

# %%
df_periodic = df_short[['ProjectCode','BillingPTD', 'CostPTD', 'EffortAmtPED','EmpCountPED', 'HoursPTD', 'IndiaCountPED',
       'IndiaHrsPED', 'LaborRevenuePTD', 'NonIndiaHrsPED', 'OverheadPTD',
       'EngHoursPED', 'EngPctPED', 'EngProjectCountPED','OtherHoursPED', 'OtherPctPED', 'PMProjectCountPED', 'PrincipalProjectCountPED',
       'FamilyProjectCount', 'FamilyEffortPTD', 'FamilyCostPTD',
       'FamilyOverheadPTD', 'FamilyHoursPTD', 'FamilyRevenuePTD',
       'FamilyBudgetEffort', 'FamilyHoursPED',
       'FamilyEffortPED', 'FamilyIndiaCountPED', 'FamilyIndiaHrsPED',
       'LaborEffortPED', 'LaborCostPED', 'LaborHrsPED','RevenuePTD', 'LaborCostPTD',
       'LaborOverheadPTD','TotalBudgetCost',
       'TotalBudgetEffort', 'TotalBudgetHours', 'TotalHoursPED', 'DrafterAvgExp', 'DrafterCombinedExp',
       'DrafterUniqueCount','EngAvgExp', 'EngCombinedExp','TotalLaborBudgetEffort']]
df_periodic['ProjectCode'] = df_periodic['ProjectCode'].astype('|S')
df_periodic = df_periodic[df_periodic.ProjectCode.str[:2] != b'15']
df_periodic['ProjectCode'] = df_periodic['ProjectCode'].str[:8]
df_periodic['ProfitPTD'] = df_periodic['RevenuePTD'] - df_periodic['CostPTD'] - df_periodic['OverheadPTD']
df_periodic['Profit%PTD'] = df_periodic['ProfitPTD']/df['RevenuePTD']
df_periodic = df_periodic.groupby('ProjectCode').max()
# Out:
# /Users/stevendirjayanto/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':

# %%
from sklearn import preprocessing
x = df_periodic[['BillingPTD', 'CostPTD', 'EffortAmtPED','EmpCountPED', 'HoursPTD', 'IndiaCountPED',
       'IndiaHrsPED', 'LaborRevenuePTD', 'NonIndiaHrsPED', 'OverheadPTD',
       'EngHoursPED', 'EngPctPED', 'EngProjectCountPED','OtherHoursPED', 'OtherPctPED', 'PMProjectCountPED', 'PrincipalProjectCountPED',
       'FamilyProjectCount', 'FamilyEffortPTD', 'FamilyCostPTD',
       'FamilyOverheadPTD', 'FamilyHoursPTD', 'FamilyRevenuePTD',
       'FamilyBudgetEffort', 'FamilyHoursPED',
       'FamilyEffortPED', 'FamilyIndiaCountPED', 'FamilyIndiaHrsPED',
       'LaborEffortPED', 'LaborCostPED', 'LaborHrsPED','RevenuePTD', 'LaborCostPTD',
       'LaborOverheadPTD','TotalBudgetCost',
       'TotalBudgetEffort', 'TotalBudgetHours', 'TotalHoursPED', 'DrafterAvgExp', 'DrafterCombinedExp',
       'DrafterUniqueCount','EngAvgExp', 'EngCombinedExp','TotalLaborBudgetEffort','ProfitPTD']]
y = df_periodic['Profit%PTD']
normalized_X = preprocessing.normalize(x)

# Get column names first
names = df_periodic.columns

scaled_df = pd.DataFrame(normalized_X, columns=x.columns)

scaled_df['Profit%PTD'] = scaled_df['ProfitPTD']/scaled_df['RevenuePTD']

# %%
import matplotlib.pyplot as plt
import numpy as np

corr = scaled_df.corr(method='kendall')
fig = plt.figure(figsize = (15, 15))
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(df_periodic.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(df_periodic.columns)
ax.set_yticklabels(df_periodic.columns)
plt.show()

# %%
pd.set_option('display.max_columns', 500)
series = corr.loc[["Profit%PTD"],['EffortAmtPED','EmpCountPED', 'HoursPTD', 'IndiaCountPED',
       'IndiaHrsPED', 'LaborRevenuePTD', 'NonIndiaHrsPED', 'OverheadPTD',
       'EngHoursPED', 'EngPctPED', 'EngProjectCountPED','OtherHoursPED', 'OtherPctPED', 'PMProjectCountPED', 'PrincipalProjectCountPED',
       'FamilyProjectCount', 'FamilyEffortPTD', 'FamilyCostPTD',
       'FamilyOverheadPTD', 'FamilyHoursPTD', 'FamilyRevenuePTD',
       'FamilyBudgetEffort', 'FamilyHoursPED',
       'FamilyEffortPED', 'FamilyIndiaCountPED', 'FamilyIndiaHrsPED',
       'LaborEffortPED', 'LaborCostPED', 'LaborHrsPED', 'LaborCostPTD',
       'LaborOverheadPTD','TotalBudgetCost',
       'TotalBudgetEffort', 'TotalBudgetHours', 'TotalHoursPED', 'DrafterAvgExp', 'DrafterCombinedExp',
       'DrafterUniqueCount','EngAvgExp', 'EngCombinedExp','TotalLaborBudgetEffort','LaborRevenuePTD']].squeeze()
#series = series[series >0.4]
#series = series[series<0.8]
series
# Out:
# EffortAmtPED               -0.089434
# EmpCountPED                -0.056876
# HoursPTD                   -0.388597
# IndiaCountPED              -0.034420
# IndiaHrsPED                -0.034277
# LaborRevenuePTD             0.358774
# NonIndiaHrsPED             -0.074096
# OverheadPTD                -0.641831
# EngHoursPED                -0.039469
# EngPctPED                   0.075169
# EngProjectCountPED          0.095378
# OtherHoursPED              -0.039660
# OtherPctPED                -0.038599
# PMProjectCountPED           0.094185
# PrincipalProjectCountPED    0.091175
# FamilyProjectCount          0.124600
# FamilyEffortPTD            -0.408213
# FamilyCostPTD              -0.488395
# FamilyOverheadPTD          -0.591568
# FamilyHoursPTD             -0.341142
# FamilyRevenuePTD            0.396113
# FamilyBudgetEffort          0.367620
# FamilyHoursPED             -0.067204
# FamilyEffortPED            -0.083676
# FamilyIndiaCountPED        -0.035204
# ...

# %%
df_periodic_short = df_periodic[["EffortAmtPED","EmpCountPED","NonIndiaHrsPED","EngHoursPED", "FamilyEffortPTD",
                                "FamilyCostPTD", "FamilyOverheadPTD", "FamilyHoursPTD", "FamilyRevenuePTD",
                                "FamilyBudgetEffort", "FamilyHoursPED", "FamilyEffortPED", "LaborEffortPED", 
                                "LaborCostPED","LaborHrsPED", "TotalBudgetHours","TotalHoursPED",
                                "DrafterUniqueCount","EngCombinedExp"]]
corr = df_periodic_short.corr()
fig = plt.figure(figsize = (15, 15))
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(df_periodic_short.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(df_periodic.columns)
ax.set_yticklabels(df_periodic.columns)
plt.show()

# %%
X = df_periodic.loc[:,['EffortAmtPED','EmpCountPED', 'HoursPTD', 'IndiaCountPED',
       'IndiaHrsPED', 'LaborRevenuePTD', 'NonIndiaHrsPED', 'OverheadPTD',
       'EngHoursPED', 'EngPctPED', 'EngProjectCountPED','OtherHoursPED', 'OtherPctPED', 'PMProjectCountPED', 'PrincipalProjectCountPED',
       'FamilyProjectCount', 'FamilyEffortPTD', 'FamilyCostPTD',
       'FamilyOverheadPTD', 'FamilyHoursPTD', 'FamilyRevenuePTD',
       'FamilyBudgetEffort', 'FamilyHoursPED',
       'FamilyEffortPED', 'FamilyIndiaCountPED', 'FamilyIndiaHrsPED',
       'LaborEffortPED', 'LaborCostPED', 'LaborHrsPED', 'LaborCostPTD',
       'LaborOverheadPTD','TotalBudgetCost',
       'TotalBudgetEffort', 'TotalBudgetHours', 'TotalHoursPED', 'DrafterAvgExp', 'DrafterCombinedExp',
       'DrafterUniqueCount','EngAvgExp', 'EngCombinedExp','TotalLaborBudgetEffort']]
y = df_periodic.loc[:,["ProfitPTD"]]    #target column i.e price range
from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt
model = ExtraTreesRegressor()
model.fit(X,y)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# /Users/stevendirjayanto/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/stevendirjayanto/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   app.launch_new_instance()
# [1.06027640e-04 2.26224870e-04 5.48212215e-02 3.21059212e-05
#  1.35730148e-04 2.45022443e-01 4.82984278e-04 1.16835254e-01
#  1.29490683e-03 3.46316228e-05 5.65893483e-04 2.02958057e-04
#  1.36741048e-04 1.21285257e-04 1.96585271e-04 1.55014770e-04
#  1.51939536e-03 8.78196001e-05 7.99312580e-05 3.55372347e-03
#  7.84409833e-04 8.17373261e-03 8.42654487e-04 3.40414287e-05
#  4.56117442e-05 5.32881198e-05 4.56879293e-04 1.01689957e-04
# ...

# %%
df_mean = df_short[['ProjectCode','BillingMTD', 'BillingPTD',
       'CostMTD', 'CostPTD','TotalBudgetCost',
       'TotalBudgetEffort', 'TotalBudgetHours', 'TotalHoursPED', 'DrafterAvgExp', 'DrafterCombinedExp',
       'DrafterUniqueCount','EngAvgExp', 'EngCombinedExp','RevenuePTD','TotalLaborBudgetEffort','RevenueMTD']]
df_mean['ProjectCode'] = df_mean['ProjectCode'].astype('|S')
df_mean = df_mean[df_mean.ProjectCode.str[:2] != b'15']
df_mean['ProjectCode'] = df_mean['ProjectCode'].str[:8]
df_mean['ProfitMTD'] = df_mean['RevenueMTD'] - df_mean['CostMTD']
df_mean['ProfitPTD'] = df_mean['RevenuePTD'] - df_mean['CostPTD']
df_mean = df_mean.groupby('ProjectCode').max()

import matplotlib.pyplot as plt
import numpy as np

corr = df_mean.corr()
fig = plt.figure(figsize = (15, 15))
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(df_mean.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(df_mean.columns)
ax.set_yticklabels(df_mean.columns)
plt.show()

# %%
df_mean
# Out:
#                BillingMTD     BillingPTD      CostMTD        CostPTD  \
# ProjectCode
# b'12040010'    462.133077    2026.911538   167.393846     751.079231
# b'23000020'   2211.453544   20894.426709   610.638671    5966.584873
# b'23000036'   3058.126548   41947.398929  1530.516429   21060.017738
# b'23000280'    857.142857    3642.857143    30.994286     185.965714
# b'23000320'   4911.780000   43169.177273  1882.006909   19084.198909
# b'23000330'   1356.286944   13769.180556   224.258889    1866.338333
# b'23000360'    445.684615    3741.400000    46.306154     240.550769
# b'23000430'   3024.065481   40855.299712  1837.609038   30383.708365
# b'23000500'   1887.250459   19108.392936   637.908991    7728.044128
# b'23000530'  14190.853433   84077.794925  5956.475522   36012.874478
# b'23000550'   4363.505865   68323.266154  3890.318846   56757.065865
# b'23000551'   4052.642294   32005.905000  2087.885912   17031.017059
# ...

# %%
corr.loc[["ProfitMTD","ProfitPTD"],['TotalBudgetCost',
       'TotalBudgetEffort', 'TotalBudgetHours', 'TotalHoursPED', 'DrafterAvgExp', 'DrafterCombinedExp',
       'DrafterUniqueCount', 'DraftingPctPED', 'EngAvgExp', 'EngCombinedExp','TotalLaborBudgetEffort']]

# %%
df_city = df_short[['ProjectCode','BillingMTD', 'BillingPTD', 'ClientCountry',
       'CostMTD', 'CostPTD','RevenuePTD','RevenueMTD']]
df_city['ClientCountry'] = df_city['ClientCountry'].str.lower()
df_city['ProjectCode'] = df_city['ProjectCode'].astype('|S')
df_city = df_city[df_city.ProjectCode.str[:2] != b'15']
df_city['ProjectCode'] = df_city['ProjectCode'].str[:8]
df_city['ProfitMTD'] = df_city['RevenueMTD'] - df_city['CostMTD']
df_city['ProfitPTD'] = df_city['RevenuePTD'] - df_city['CostPTD']
df_city = df_city.groupby(['ProjectCode','ClientCountry']).max()
# Out:
# /Users/stevendirjayanto/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/stevendirjayanto/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df_temp = df_city.reset_index(level=[0,1])

# %%
#df_temp = df_temp[df_temp.ProfitPTD < 40000]
#df_temp = df_temp[df_temp.ProfitPTD > 0]
len(df_temp)
# Out:
# 6020

# %%
import seaborn as sns
plt.figure(figsize=(50, 20))
sns.catplot(x="ClientCountry", y="ProfitPTD", data=df_temp);

# %%
df_temp.head()
# Out:
#     ProjectCode ClientState  BillingMTD  BillingPTD  CostMTD   CostPTD  \
# 0   b'12040010'       texas     6007.73    26349.85  2176.12   9764.03
# 3   b'23000280'    missouri     6000.00    25500.00   216.96   1301.76
# 6   b'23000360'       texas     5793.90    48638.20   601.98   3127.16
# 15  b'23000640'     florida     2000.00    16072.60   377.92   3023.36
# 22  b'23001010'       texas     8901.86    26137.35  3610.02  13672.41
#
#     RevenuePTD  RevenueMTD  ProfitMTD  ProfitPTD
# 0     26886.73     6007.88    3831.76   17122.70
# 3     28200.00     6000.00    5783.04   26898.24
# 6      9553.72     1986.27    1384.29    6426.56
# 15    11168.80     2000.00    1622.08    8145.44
# 22    29571.10     7260.38    3650.36   15898.69

# %%
df_anova = pd.get_dummies(df_temp,columns = ["ClientState"])
# Out:
#        ProjectCode  BillingMTD  BillingPTD    CostMTD    CostPTD  RevenuePTD  \
# 0      b'12040010'     6007.73    26349.85    2176.12    9764.03    26886.73
# 3      b'23000280'     6000.00    25500.00     216.96    1301.76    28200.00
# 6      b'23000360'     5793.90    48638.20     601.98    3127.16     9553.72
# 15     b'23000640'     2000.00    16072.60     377.92    3023.36    11168.80
# 22     b'23001010'     8901.86    26137.35    3610.02   13672.41    29571.10
# 24     b'23010020'     1233.58    22279.00     557.78    9392.46    26445.63
# 27     b'23010060'     2500.00    26000.00    1915.07   17185.88    44863.86
# 31     b'23010120'     4043.39    21295.61    1773.50    8867.50    21486.51
# 37     b'23010210'     6099.61    48117.73    2250.85   27010.20    62970.25
# 38     b'23010220'     6000.00    27449.42    1665.06    9990.36    36047.10
# 41     b'23010250'     5475.00    56878.50    1700.16   18030.25    57069.41
# ...

# %%
df_anova = pd.get_dummies(df_temp,columns = ["ClientState"])
df_anova_final = df_anova.iloc[:,8:]
for index, row in df_anova.iterrows():
    profit = df_anova.loc[index,"ProfitPTD"]
    df_anova_final = df_anova_final*profit

# %%
df_anova_final
# Out:
#        ProfitPTD  ClientState_alabama  ClientState_arizona  \
# 0       17122.70                    0                    0
# 3       26898.24                    0                    0
# 6        6426.56                    0                    0
# 15       8145.44                    0                    0
# 22      15898.69                    0                    0
# 24      17053.17                    0                    0
# 27      27677.98                    0                    0
# 31      12619.01                    0                    0
# 37      35960.05                    0                    0
# 38      26056.74                    0                    0
# 41      39039.16                    0                    0
# 44       4554.74                    0                    0
# 58       6942.73                    0                    0
# 60      22864.65                    0                    0
# 61       9078.93                    0                    0
# ...

# %%
df_anova_final = df_anova.iloc[:,8:]
df_anova_final
# Out:
#        ProfitPTD  ClientState_alabama  ClientState_arizona  \
# 0       17122.70                    0                    0
# 3       26898.24                    0                    0
# 6        6426.56                    0                    0
# 15       8145.44                    0                    0
# 22      15898.69                    0                    0
# 24      17053.17                    0                    0
# 27      27677.98                    0                    0
# 31      12619.01                    0                    0
# 37      35960.05                    0                    0
# 38      26056.74                    0                    0
# 41      39039.16                    0                    0
# 44       4554.74                    0                    0
# 58       6942.73                    0                    0
# 60      22864.65                    0                    0
# 61       9078.93                    0                    0
# ...

# %%
plt.figure(figsize=(20, 20))
sns.catplot(x="ClientState", y="ProfitMTD", data=df_temp);
